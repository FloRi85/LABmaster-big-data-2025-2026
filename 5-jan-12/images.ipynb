# %%
from os.path import join

import cv2
import matplotlib.pyplot as plt

import numpy as np

wd = "."
im_path = join(wd, "example.png")

image = cv2.imread(im_path)

plt.hist(image.ravel(), 10)
# Out:
# (array([  36654.,   22398.,   15534.,   15483.,   16641.,   20562.,
#           15378.,   18180.,   17262., 1577736.]),
#  array([ 25.,  48.,  71.,  94., 117., 140., 163., 186., 209., 232., 255.]),
#  <BarContainer object of 10 artists>)

# %%
gray_image = np.mean(image, axis=-1)
gray_image
# Out:
# array([[255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        ...,
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.],
#        [255., 255., 255., ..., 255., 255., 255.]], shape=(969, 604))

# %%
black_white = np.where(gray_image<125,0,255)
_, black_white_cv = cv2.threshold(gray_image, 125, 255, cv2.THRESH_BINARY)

plt.hist(black_white_cv.ravel(), 10)
# Out:
# (array([ 32003.,      0.,      0.,      0.,      0.,      0.,      0.,
#              0.,      0., 553273.]),
#  array([  0. ,  25.5,  51. ,  76.5, 102. , 127.5, 153. , 178.5, 204. ,
#         229.5, 255. ]),
#  <BarContainer object of 10 artists>)
